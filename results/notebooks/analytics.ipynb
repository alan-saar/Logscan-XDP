# %% [markdown]
# # Análise Comparativa Científica: Logscan-XDP
#
# Este notebook apresenta a análise comparativa entre os resultados obtidos pela baseline pura (User Space com Drain3) e a arquitetura acelerada híbrida (Kernel eBPF CO-RE + User DeepLog LSTM em CPU) sob a rede virtual distribuída do *Containerlab*.

# %%
import pandas as pd
import os

df_b = pd.read_csv('../data/baseline.csv')
df_e = pd.read_csv('../data/ebpf_accelerated.csv')

print("=== METRICAS DA BASELINE (USER SPACE DRAIN3) ===")
display(df_b)
print("\n=== METRICAS DA ACELERAÇÃO (KERNEL EBPF + DEEPLOG CPU) ===")
display(df_e)

# %% [markdown]
# ## Figuras Científicas Seaborn Premium Geradas para o Artigo

# %% [markdown]
# ### 1. Acurácia Comparativa da IA
# ![Acurácia Comparativa](../images/01_acuracia_comparativa.png)

# %% [markdown]
# ### 2. Ganho de Latência (Tempo Total)
# ![Ganho de Latência](../images/02_ganho_latencia.png)

# %% [markdown]
# ### 3. Eficiência e Leveza de Memória RAM
# ![Eficiência de RAM](../images/03_eficiencia_ram.png)

# %% [markdown]
# ### 4. O Falso Dilema da Rede (Perda de Pacotes vs F1-Score)
# ![O Falso Dilema](../images/04_falso_dilema_rede.png)
